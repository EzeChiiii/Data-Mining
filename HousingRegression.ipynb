# %%
import pandas as pd
import seaborn as sns
import matplotlib as plt
import numpy as np

# %%
df = pd.read_csv('train.csv')

# %%
df.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature MiscVal MoSold  \
# 0         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 1         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      5
# 2         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      9
# 3         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 4         Lvl    AllPub  ...        0    NaN   NaN         NaN       0     12
#
#   YrSold  SaleType  SaleCondition  SalePrice
# 0   2008        WD         Normal     208500
# 1   2007        WD         Normal     181500
# 2   2008        WD         Normal     223500
# 3   2006        WD        Abnorml     140000
# 4   2008        WD         Normal     250000
#
# [5 rows x 81 columns]

# %%
df.shape
# Out:
# (1460, 81)

# %%
df.describe()
# Out:
#                 Id   MSSubClass  LotFrontage        LotArea  OverallQual  \
# count  1460.000000  1460.000000  1201.000000    1460.000000  1460.000000
# mean    730.500000    56.897260    70.049958   10516.828082     6.099315
# std     421.610009    42.300571    24.284752    9981.264932     1.382997
# min       1.000000    20.000000    21.000000    1300.000000     1.000000
# 25%     365.750000    20.000000    59.000000    7553.500000     5.000000
# 50%     730.500000    50.000000    69.000000    9478.500000     6.000000
# 75%    1095.250000    70.000000    80.000000   11601.500000     7.000000
# max    1460.000000   190.000000   313.000000  215245.000000    10.000000
#
#        OverallCond    YearBuilt  YearRemodAdd   MasVnrArea   BsmtFinSF1  ...  \
# count  1460.000000  1460.000000   1460.000000  1452.000000  1460.000000  ...
# mean      5.575342  1971.267808   1984.865753   103.685262   443.639726  ...
# std       1.112799    30.202904     20.645407   181.066207   456.098091  ...
# min       1.000000  1872.000000   1950.000000     0.000000     0.000000  ...
# 25%       5.000000  1954.000000   1967.000000     0.000000     0.000000  ...
# 50%       5.000000  1973.000000   1994.000000     0.000000   383.500000  ...
# 75%       6.000000  2000.000000   2004.000000   166.000000   712.250000  ...
# max       9.000000  2010.000000   2010.000000  1600.000000  5644.000000  ...
#
#         WoodDeckSF  OpenPorchSF  EnclosedPorch    3SsnPorch  ScreenPorch  \
# count  1460.000000  1460.000000    1460.000000  1460.000000  1460.000000
# mean     94.244521    46.660274      21.954110     3.409589    15.060959
# std     125.338794    66.256028      61.119149    29.317331    55.757415
# min       0.000000     0.000000       0.000000     0.000000     0.000000
# 25%       0.000000     0.000000       0.000000     0.000000     0.000000
# 50%       0.000000    25.000000       0.000000     0.000000     0.000000
# 75%     168.000000    68.000000       0.000000     0.000000     0.000000
# max     857.000000   547.000000     552.000000   508.000000   480.000000
#
#           PoolArea       MiscVal       MoSold       YrSold      SalePrice
# count  1460.000000   1460.000000  1460.000000  1460.000000    1460.000000
# mean      2.758904     43.489041     6.321918  2007.815753  180921.195890
# std      40.177307    496.123024     2.703626     1.328095   79442.502883
# min       0.000000      0.000000     1.000000  2006.000000   34900.000000
# 25%       0.000000      0.000000     5.000000  2007.000000  129975.000000
# 50%       0.000000      0.000000     6.000000  2008.000000  163000.000000
# 75%       0.000000      0.000000     8.000000  2009.000000  214000.000000
# max     738.000000  15500.000000    12.000000  2010.000000  755000.000000
#
# [8 rows x 38 columns]

# %%
corr = df.corr() # allows us to get the correlations
sns.set(rc = {'figure.figsize':(30,20)})
sns.heatmap(corr, annot=True) # annot=True adds the values
# Out:
# <AxesSubplot:>

# %%
sns.set(rc = {'figure.figsize':(8,8)})
sns.scatterplot(data=df, x='1stFlrSF', y='SalePrice', hue='GrLivArea')
# Out:
# <AxesSubplot:xlabel='1stFlrSF', ylabel='SalePrice'>

# %%
sns.set(rc = {'figure.figsize':(8,8)})
sns.scatterplot(data=df, x='GrLivArea', y='SalePrice', hue='1stFlrSF')
# Out:
# <AxesSubplot:xlabel='GrLivArea', ylabel='SalePrice'>

# %%
sns.set(rc = {'figure.figsize':(8,8)})
sns.scatterplot(data=df, x='GrLivArea', y='TotalBsmtSF', hue='SalePrice')
# Out:
# <AxesSubplot:xlabel='GrLivArea', ylabel='TotalBsmtSF'>

# %%
df.isna().sum()
# Out:
# Id               0
# MSSubClass       0
# MSZoning         0
# LotArea          0
# Street           0
#                 ..
# MoSold           0
# YrSold           0
# SaleType         0
# SaleCondition    0
# SalePrice        0
# Length: 62, dtype: int64

# %%
df = df.dropna(axis=1)

# %%
df.isna().sum()
# Out:
# Id               0
# MSSubClass       0
# MSZoning         0
# LotArea          0
# Street           0
#                 ..
# MoSold           0
# YrSold           0
# SaleType         0
# SaleCondition    0
# SalePrice        0
# Length: 62, dtype: int64

# %%
df.columns
# Out:
# Index(['Id', 'MSSubClass', 'MSZoning', 'LotArea', 'Street', 'LotShape',
#        'LandContour', 'Utilities', 'LotConfig', 'LandSlope', 'Neighborhood',
#        'Condition1', 'Condition2', 'BldgType', 'HouseStyle', 'OverallQual',
#        'OverallCond', 'YearBuilt', 'YearRemodAdd', 'RoofStyle', 'RoofMatl',
#        'Exterior1st', 'Exterior2nd', 'ExterQual', 'ExterCond', 'Foundation',
#        'BsmtFinSF1', 'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF', 'Heating',
#        'HeatingQC', 'CentralAir', '1stFlrSF', '2ndFlrSF', 'LowQualFinSF',
#        'GrLivArea', 'BsmtFullBath', 'BsmtHalfBath', 'FullBath', 'HalfBath',
#        'BedroomAbvGr', 'KitchenAbvGr', 'KitchenQual', 'TotRmsAbvGrd',
#        'Functional', 'Fireplaces', 'GarageCars', 'GarageArea', 'PavedDrive',
#        'WoodDeckSF', 'OpenPorchSF', 'EnclosedPorch', '3SsnPorch',
#        'ScreenPorch', 'PoolArea', 'MiscVal', 'MoSold', 'YrSold', 'SaleType',
#        'SaleCondition', 'SalePrice'],
#       dtype='object')

# %%
sns.scatterplot(x='TotalBsmtSF', y='SalePrice', data=df)
# Out:
# <AxesSubplot:xlabel='TotalBsmtSF', ylabel='SalePrice'>

# %%
sns.scatterplot(x='GarageArea', y='SalePrice', data=df)
# Out:
# <AxesSubplot:xlabel='GarageArea', ylabel='SalePrice'>

# %%
sns.scatterplot(x='2ndFlrSF', y='SalePrice', data=df)
# Out:
# <AxesSubplot:xlabel='2ndFlrSF', ylabel='SalePrice'>

# %%
y = df['SalePrice']

# %%
X = df[['1stFlrSF','GarageArea', 'TotalBsmtSF']]

# %%
from sklearn.preprocessing import StandardScaler

scaled = StandardScaler().fit_transform(X)

# %%
X_scaled = pd.DataFrame(scaled, columns = X.columns)

X_scaled
# Out:
#       1stFlrSF  GarageArea  TotalBsmtSF
# 0    -0.793434    0.351000    -0.459303
# 1     0.257140   -0.060731     0.466465
# 2    -0.627826    0.631726    -0.313369
# 3    -0.521734    0.790804    -0.687324
# 4    -0.045611    1.698485     0.199680
# ...        ...         ...          ...
# 1455 -0.542435   -0.060731    -0.238122
# 1456  2.355701    0.126420     1.104925
# 1457  0.065656   -1.033914     0.215641
# 1458 -0.218982   -1.090059     0.046905
# 1459  0.241615   -0.921624     0.452784
#
# [1460 rows x 3 columns]

# %%
from sklearn.feature_selection import SelectKBest, f_regression

fs = SelectKBest(score_func = f_regression, k=2)
best = fs.fit_transform(X_scaled, y)

# %%
features = np.array(list(X_scaled.columns))

best_features = features[fs.get_support()]
print(best_features)
# Out:
# ['GarageArea' 'TotalBsmtSF']

# %%
from sklearn.model_selection import train_test_split

# %%
from sklearn.linear_model import LinearRegression

# %%
import statsmodels.api as sma

# %%
sns.scatterplot(x='TotalBsmtSF', y='SalePrice', data=df)
# Out:
# <AxesSubplot:xlabel='TotalBsmtSF', ylabel='SalePrice'>

# %%
X_train,X_test, y_train,y_test = train_test_split(X_scaled[best_features],y,test_size = 0.3, random_state = 7)

# %%
X_train.shape,y_train.shape,X_test.shape,y_test.shape
# Out:
# ((1022, 2), (1022,), (438, 2), (438,))

# %%
from sklearn import linear_model
lr = linear_model.LinearRegression()

# %%
lr_model = lr.fit(X_train,y_train)

# %%
#look at the intercept and slope of the model. 

print('Model Intercept:',lr_model.intercept_)
print('Model Slope:' ,lr_model.coef_[0])
#Get our coefficient of determination

print('Coefficient of Determination:',lr_model.score(X_test, y_test))
coeff_df = pd.DataFrame(lr_model.coef_, X_test.columns, columns=['Coefficients'])
coeff_df
y_pred = lr_model.predict(X_test)

from sklearn import metrics
mae = metrics.mean_absolute_error(y_test, y_pred)
mse = metrics.mean_squared_error(y_test, y_pred)
rmse = metrics.mean_squared_error(y_test, y_pred,squared = False)

print('Mean Absolute Error:', mae)
print('Mean Square Error:', mse)
print('Root Mean Square Error:', rmse)
# Out:
# Model Intercept: 180943.94375948136
# Model Slope: 35132.2495782819
# Coefficient of Determination: 0.4674546908156516
# Mean Absolute Error: 38147.40797363391
# Mean Square Error: 3317622190.840306
# Root Mean Square Error: 57598.80372751075

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X_scaled[best_features], y, test_size = 0.4, random_state = 0)

# %%
X_train.shape,y_train.shape,X_test.shape,y_test.shape
# Out:
# ((876, 2), (876,), (584, 2), (584,))

# %%
from sklearn import linear_model
lr = linear_model.LinearRegression()

# %%
lr_model = lr.fit(X_train, y_train)

# %%
print('Model Intercept:',lr_model.intercept_)
print('Model Slope:' ,lr_model.coef_[0])
print('Coefficient of Determination:',lr_model.score(X_test, y_test))


coeff_df = pd.DataFrame(lr_model.coef_, X_test.columns, columns=['Coefficients'])
coeff_df
# Out:
# Model Intercept: 181307.0789110597
# Model Slope: 36060.68569953592
# Coefficient of Determination: 0.44970564786912126
#              Coefficients
# GarageArea   36060.685700
# TotalBsmtSF  35574.727096

# %%
plot_rnet = sns.regplot(data = df,x='TotalBsmtSF',y='SalePrice',line_kws={'color':'black',
                                                                           'label':'$y=%5.4sx+%5.5s$'%(lr_model.coef_[1],lr_model.intercept_)})

# %%
plot_rnet = sns.regplot(data = df,x='GarageArea',y='SalePrice', line_kws={'color':'black',
                                                                           'label':'$y=%5.4sx+%5.5s$'%(lr_model.coef_[1],lr_model.intercept_)})

# %%
y_pred = lr_model.predict(X_test)

# %%
from sklearn import metrics
mae = metrics.mean_absolute_error(y_test,y_pred)
print('Mean Absolute Error:', mae)
# Out:
# Mean Absolute Error: 38147.40797363391

# %%
mse = metrics.mean_squared_error(y_test,y_pred)
print('Mean Square Error:', mse)
# Out:
# Mean Square Error: 3317622190.840306

# %%
rmse = metrics.mean_squared_error(y_test,y_pred,squared = False)
print('Root Mean Square Error:', rmse)
# Out:
# Root Mean Square Error: 57598.80372751075

# %%
X = X = df[['OverallQual', 'GrLivArea', 'GarageArea','GarageCars']]
y = df['SalePrice']

# %%
from sklearn.preprocessing import StandardScaler

scaled = StandardScaler().fit_transform(X)

# %%
X_scaled = pd.DataFrame(scaled, columns = X.columns)
X_scaled
# Out:
#       OverallQual  GrLivArea  GarageArea  GarageCars
# 0        0.651479   0.370333    0.351000    0.311725
# 1       -0.071836  -0.482512   -0.060731    0.311725
# 2        0.651479   0.515013    0.631726    0.311725
# 3        0.651479   0.383659    0.790804    1.650307
# 4        1.374795   1.299326    1.698485    1.650307
# ...           ...        ...         ...         ...
# 1455    -0.071836   0.250402   -0.060731    0.311725
# 1456    -0.071836   1.061367    0.126420    0.311725
# 1457     0.651479   1.569647   -1.033914   -1.026858
# 1458    -0.795151  -0.832788   -1.090059   -1.026858
# 1459    -0.795151  -0.493934   -0.921624   -1.026858
#
# [1460 rows x 4 columns]

# %%
from sklearn.feature_selection import SelectKBest, f_regression

fs = SelectKBest(score_func = f_regression, k=2)
best = fs.fit_transform(X_scaled, y)

# %%
features = np.array(list(X_scaled.columns))

best_features = features[fs.get_support()]
print(best_features)
# Out:
# ['OverallQual' 'GrLivArea']

# %%
sns.regplot(data=df, y='SalePrice', x='OverallQual', fit_reg=True)
# Out:
# <AxesSubplot:xlabel='OverallQual', ylabel='SalePrice'>

# %%
sns.regplot(data=df, y='SalePrice', x='GrLivArea', fit_reg=True)
# Out:
# <AxesSubplot:xlabel='GrLivArea', ylabel='SalePrice'>

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X_scaled[best_features],y,test_size=0.3, random_state = 7)

# %%
X_train.shape,y_train.shape,X_test.shape,y_test.shape
# Out:
# ((1022, 2), (1022,), (438, 2), (438,))

# %%
lr = LinearRegression()
lr_model = lr.fit(X_train, y_train)

# %%
import statsmodels.api as sma
X2 = sma.add_constant(X_train)

est = sma.OLS(y_train,X2) 
est2 = est.fit()

# %%
print(est2.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:              SalePrice   R-squared:                       0.697
# Model:                            OLS   Adj. R-squared:                  0.697
# Method:                 Least Squares   F-statistic:                     1173.
# Date:                Sun, 30 Oct 2022   Prob (F-statistic):          4.61e-265
# Time:                        22:12:16   Log-Likelihood:                -12335.
# No. Observations:                1022   AIC:                         2.468e+04
# Df Residuals:                    1019   BIC:                         2.469e+04
# Df Model:                           2
# Covariance Type:            nonrobust
# ===============================================================================
#                   coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------
# const        1.808e+05   1324.609    136.460      0.000    1.78e+05    1.83e+05
# OverallQual  4.533e+04   1641.381     27.619      0.000    4.21e+04    4.86e+04
# GrLivArea     2.51e+04   1647.659     15.231      0.000    2.19e+04    2.83e+04
# ==============================================================================
# Omnibus:                      225.733   Durbin-Watson:                   2.051
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             5640.502
# Skew:                           0.355   Prob(JB):                         0.00
# Kurtosis:                      14.487   Cond. No.                         2.00
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
print('Intercept:',lr_model.intercept_)
print('Coefficient:',lr_model.coef_[1])
# Out:
# Intercept: 180755.85958491953
# Coefficient: 25095.603633959738

# %%
y_pred = lr_model.predict(X_test)

# %%
from sklearn import metrics
mae = metrics.mean_absolute_error(y_test,y_pred)
print(mae)
# Out:
# 29344.985427909152

# %%
mse = metrics.mean_squared_error(y_test,y_pred)
print(mse)
# Out:
# 1910532686.7556455

# %%
rmse = metrics.mean_squared_error(y_test, y_pred, squared = False)
print(rmse)
# Out:
# 43709.64066147931

# %%
X
# Out:
#       OverallQual  GrLivArea  GarageArea  GarageCars
# 0               7       1710         548           2
# 1               6       1262         460           2
# 2               7       1786         608           2
# 3               7       1717         642           3
# 4               8       2198         836           3
# ...           ...        ...         ...         ...
# 1455            6       1647         460           2
# 1456            6       2073         500           2
# 1457            7       2340         252           1
# 1458            5       1078         240           1
# 1459            5       1256         276           1
#
# [1460 rows x 4 columns]

# %%
X = df[['OverallQual', 'GrLivArea', 'GarageArea','GarageCars']]
y = df['SalePrice']
scaled = StandardScaler().fit_transform(X)

# %%
scaled = StandardScaler().fit_transform(X)

# %%
X_scaled = pd.DataFrame(scaled, columns = X.columns)

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X_scaled,y,test_size=0.3, random_state = 7)

# %%
X_train.shape,y_train.shape,X_test.shape,y_test.shape
# Out:
# ((1022, 4), (1022,), (438, 4), (438,))

# %%
lr_model = lr.fit(X_train, y_train)

# %%
X2 = sma.add_constant(X_train)

est = sma.OLS(y_train,X2) 
est2 = est.fit()

# %%
print(est2.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:              SalePrice   R-squared:                       0.731
# Model:                            OLS   Adj. R-squared:                  0.730
# Method:                 Least Squares   F-statistic:                     690.7
# Date:                Sun, 30 Oct 2022   Prob (F-statistic):          4.58e-288
# Time:                        22:19:15   Log-Likelihood:                -12275.
# No. Observations:                1022   AIC:                         2.456e+04
# Df Residuals:                    1017   BIC:                         2.458e+04
# Df Model:                           4
# Covariance Type:            nonrobust
# ===============================================================================
#                   coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------
# const        1.809e+05   1250.254    144.661      0.000    1.78e+05    1.83e+05
# OverallQual  3.652e+04   1741.458     20.970      0.000    3.31e+04    3.99e+04
# GrLivArea    2.179e+04   1593.318     13.674      0.000    1.87e+04    2.49e+04
# GarageArea   7251.8151   2724.410      2.662      0.008    1905.708    1.26e+04
# GarageCars   1.135e+04   2730.295      4.157      0.000    5991.436    1.67e+04
# ==============================================================================
# Omnibus:                      267.894   Durbin-Watson:                   2.043
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             7086.148
# Skew:                           0.580   Prob(JB):                         0.00
# Kurtosis:                      15.848   Cond. No.                         4.95
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
print('Intercept:',lr_model.intercept_)
print('Coefficient:',lr_model.coef_[1])
# Out:
# Intercept: 180862.34987845275
# Coefficient: 21786.673067090574

# %%
y_pred = lr_model.predict(X_test)

# %%
mae = metrics.mean_absolute_error(y_test,y_pred)
print(mae)
# Out:
# 28359.535889081053

# %%
mse = metrics.mean_squared_error(y_test,y_pred)
print(mse)
# Out:
# 1795867681.6697292

# %%
rmse = metrics.mean_squared_error(y_test, y_pred, squared = False)
print(rmse)
# Out:
# 42377.679050058054
